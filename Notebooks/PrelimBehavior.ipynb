# %%
import matplotlib.pyplot as plt
import sys
paths = [r'C:\Users\wm228\PycharmProjects\CircleTrack', r'C:\Users\wm228\Documents\GitHub\CaImaging']
[sys.path.append(path) for path in paths]
from CircleTrack.BehaviorFunctions import *

# %%
folder = r'C:\Users\wm228\PycharmProjects\CircleTrack\CircleTrack\Notebooks\data\Mouse4\02_01_2020\H15_M37_S17'
data = Process(folder)
fig = plt.figure(figsize=(6, 8.5))
for i in range(8):
    ax = fig.add_subplot(4, 2, i + 1)
    approach_speed(data.behavior_df, data.lin_ports[i], ax=ax, window=(-30, 30), dist_thresh=0.04)
fig.tight_layout()
# Out:
# BehaviorVideo not found.
