# %%
import matplotlib.pyplot as plt
import sys
paths = [r'C:\Users\wm228\PycharmProjects\CircleTrack', r'C:\Users\wm228\Documents\GitHub\CaImaging']
sys.path.extend(paths)
from CircleTrack.scripts import PlotApproaches

# %%
PlotApproaches(r'D:\Projects\CircleTrack\Mouse4\01_30_2020\H16_M50_S22')

# %%
PlotApproaches(r'D:\Projects\CircleTrack\Mouse4\02_01_2020\H15_M37_S17')
